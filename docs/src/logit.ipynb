# %% [markdown]
# # Bayesian Logistic Regression

# %%
using CSV, DataFrames, LinearAlgebra, BayesLaplace
using Plots, PlotThemes
theme(:juno)

# %%
xs, y = toy_data_linear(100)
X = transpose(hcat(xs...))
𝑴 = bayes_logreg(X, y)
p_plugin = plot_contour(X,y,𝑴,title="Plugin",type=:plugin)
p_laplace = plot_contour(X,y,𝑴,title="Laplace")
plot(p_plugin, p_laplace, layout=(1,2), size=(1000,400))

# %%
𝑴.𝐇 - 𝑴.𝐇₀
# Out:
# 3×3 Matrix{Float64}:
#  0.952845  0.235324  0.146967
#  0.235324  1.89968   1.61985
#  0.146967  1.61985   2.2425

# %%
𝑴.μ
# Out:
# 3-element Vector{Float64}:
#  0.16426517847386257
#  1.1431194982876713
#  1.3298407139869028
